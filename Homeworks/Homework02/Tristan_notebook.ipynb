# %% [markdown]
# # 02 - Data from the Web

# %% [markdown]
# In this homework we will extract interesting information from www.topuniversities.com and www.timeshighereducation.com, two platforms that maintain a global ranking of worldwide universities. This ranking is not offered as a downloadable dataset, so you will have to find a way to scrape the information we need! You are not allowed to download manually the entire ranking -- rather you have to understand how the server loads it in your browser. For this task, Postman with the Interceptor extension can help you greatly. We recommend that you watch this brief tutorial to understand quickly how to use it.

# %%
from bs4 import BeautifulSoup
import urllib2
import requests
import json
import string
import pandas as pd
import re
import math
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ## Data from QS ranking

# %% [markdown]
# Multiple strategies have been tested in order to find the data used to construct the table of the QS Rankings. However, only one of them led to the expected result. We opened the Web Inspector on the website. Among the ressources used by the page, a text file named 'XHR/357051.txt'  was containing the expected ranking with the desired informations. The URL_QS is leading to this file.

# %%
URL_QS = 'https://www.topuniversities.com/sites/default/files/qs-rankings-data/357051.txt?_=1508497791260'
r = requests.get(URL_QS)
page_body = r.json()
qs_df = pd.DataFrame(page_body['data'])
qs_df = qs_df.drop(['core_id','logo','guide','cc', 'nid', 'stars','score'], axis=1).head(200)

# %% [markdown]
# Additionnal informations needed to be accessed on each university webpage. We used the 'url' column, went to the university page and extracted all the number values we wanted and placed them in additionnal columns. In some cases, there were no informations on the webpage, in this case the columns are filed with NaN.

# %%
# Going on each university page for each index of the table

for index_ in range(0,qs_df.shape[0]):
    
    URL_ADD = 'https://www.topuniversities.com' + qs_df.get_value(index_, 'url')
    r = requests.get(URL_ADD)
    page_body = r.text
    soup = BeautifulSoup(page_body, 'html.parser')
    # Request all numbers that are displayed on the page, we know their order
    all_numbers = soup.findAll('div', {'class' : 'number'})
    
    # If the page contains no numbers, we will store NaN
    if not all_numbers:
        total_faculty_number = 'NaN'
        interna_faculty_number = 'NaN'
        total_students_number = 'NaN'
        interna_students_number = 'NaN'
   
    else:    
    # Total Faculty Members
        total_faculty = all_numbers[0]
        total_faculty_number = int(re.sub("[^\\d]",'',str(total_faculty)))
    
    # International Faculty Members
        interna_faculty = all_numbers[1]
        interna_faculty_number = int(re.sub("[^\\d]",'',str(interna_faculty)))
    
    # Total Students
        total_students = all_numbers[2]
        total_students_number = int(re.sub("[^\\d]",'',str(total_students)))  
    
    # International Students
        interna_students = all_numbers[3]
        interna_students_number = int(re.sub("[^\\d]",'',str(interna_students)))
    
    # Adding the found values in the columns
    qs_df.set_value(index_, 'Faculty Members - Total', total_faculty_number)
    qs_df.set_value(index_, 'Faculty Members - International', interna_faculty_number)
    qs_df.set_value(index_, 'No Students - Total', total_students_number)
    qs_df.set_value(index_, 'No Students - International', interna_students_number)
    
    clear_output()
    print('Progress', index_/2, '%')
qs_df.head(10)
# Out:
# ('Progress', 99, '%')
#           country rank_display         region  \
# 0   United States            1  North America
# 1   United States            2  North America
# 2   United States            3  North America
# 3   United States            4  North America
# 4  United Kingdom            5         Europe
# 5  United Kingdom            6         Europe
# 6  United Kingdom            7         Europe
# 7  United Kingdom            8         Europe
# 8   United States            9  North America
# 9     Switzerland           10         Europe
#
#                                                title  \
# 0        Massachusetts Institute of Technology (MIT)
# 1                                Stanford University
# 2                                 Harvard University
# 3       California Institute of Technology (Caltech)
# 4                            University of Cambridge
# 5                               University of Oxford
# 6                    UCL (University College London)
# 7                            Imperial College London
# 8                              University of Chicago
# 9  ETH Zurich - Swiss Federal Institute of Techno...
#
#                                                  url  Faculty Members - Total  \
# 0  /universities/massachusetts-institute-technolo...                   2982.0
# 1                  /universities/stanford-university                   4285.0
# 2                   /universities/harvard-university                   4350.0
# 3  /universities/california-institute-technology-...                    953.0
# 4                 /universities/university-cambridge                   5490.0
# 5                    /universities/university-oxford                   6750.0
# 6        /universities/ucl-university-college-london                   6345.0
# 7              /universities/imperial-college-london                   3930.0
# 8                   /universities/university-chicago                   2449.0
# 9  /universities/eth-zurich-swiss-federal-institu...                   2477.0
#
#    Faculty Members - International  No Students - Total  \
# 0                           1679.0              11067.0
# 1                           2042.0              15878.0
# 2                           1311.0              22429.0
# 3                            350.0               2255.0
# 4                           2278.0              18770.0
# 5                           2964.0              19720.0
# 6                           2554.0              31080.0
# 7                           2071.0              16090.0
# 8                            635.0              13557.0
# 9                           1886.0              19815.0
#
#    No Students - International
# 0                       3717.0
# 1                       3611.0
# 2                       5266.0
# 3                        647.0
# 4                       6699.0
# 5                       7353.0
# 6                      14854.0
# 7                       8746.0
# 8                       3379.0
# 9                       7563.0

# %% [markdown]
# ## Best QS university in terms of ratio between faculty members and students

# %%
def ratio(a, b):
    if b == 'NaN':
        return a
    
    a = float(a)
    b = float(b)
    if b == 0:
        return 1
    ratio = 100*b/a
    if ratio > 100:
        ratio = 1
    return ratio

# %%
# Create the ratios for every university

for index, row in qs_df.iterrows():
    if np.isfinite(row['No Students - Total']) and np.isfinite(row['No Students - International'])\
    or np.isfinite(row['No Students - Total']) and np.isfinite(row['Faculty Members - Total']):
        
        qs_df.loc[index, 'QS Ratio Int. Students'] = ratio(row['No Students - Total'], \
                                                           row['No Students - International'])
        qs_df.loc[index, 'QS Ratio Students/Staff'] = ratio(row['No Students - Total'], \
                                                            row['Faculty Members - Total'])
        

# Sort Universities with both ratios that are asked

qs_df_IntStud = qs_df.sort_values(['QS Ratio Int. Students'],ascending=[False])
qs_df_StaffStud = qs_df.sort_values(['QS Ratio Students/Staff'],ascending=[False])
qs_df_IntStud = qs_df_IntStud.reset_index(drop=True)
qs_df_StaffStud = qs_df_StaffStud.reset_index(drop=True)

# Give each university some points depending on their ratio
points = qs_df.shape[0]
for index_ in range(0,qs_df.shape[0]):
    qs_df_IntStud.set_value(index_, 'Points', points)
    qs_df_StaffStud.set_value(index_, 'Points', points)
    points -= 1

# %%
qs_df_IntStud
# Out:
#             country rank_display         region  \
# 0    United Kingdom           35         Europe
# 1       Switzerland           12         Europe
# 2    United Kingdom            8         Europe
# 3       Netherlands          200         Europe
# 4     United States          =47  North America
# 5    United Kingdom            7         Europe
# 6    United Kingdom           92         Europe
# 7         Australia          =41        Oceania
# 8    United Kingdom          127         Europe
# 9         Hong Kong           26           Asia
# 10   United Kingdom          =23         Europe
# 11      Netherlands          113         Europe
# 12   United Kingdom           57         Europe
# 13      Switzerland          =98         Europe
# 14        Australia           20        Oceania
# 15        Australia         =109        Oceania
# 16      Switzerland           10         Europe
# 17   United Kingdom          =23         Europe
# 18   United Kingdom            6         Europe
# 19   United Kingdom           34         Europe
# 20        Australia           50        Oceania
# 21   United Kingdom         =135         Europe
# 22        Australia           45        Oceania
# 23        Australia           60        Oceania
# 24   United Kingdom            5         Europe
# 25        Hong Kong           49           Asia
# 26   United Kingdom         =158         Europe
# 27   United Kingdom          =82         Europe
# 28   United Kingdom           65         Europe
# 29   United Kingdom         =173         Europe
# ..              ...          ...            ...
# 170           China         =114           Asia
# 171           Italy         =192         Europe
# 172           Japan          =76           Asia
# 173   United States         =182  North America
# 174   United States         =173  North America
# 175     Netherlands         =109         Europe
# 176           Japan          =36           Asia
# 177          Taiwan         =161           Asia
# 178     South Korea          =36           Asia
# 179   United States         =195  North America
# 180           Japan         =122           Asia
# 181   United States           80  North America
# 182           China           62           Asia
# 183          Norway         =164         Europe
# 184           Italy         =188         Europe
# 185           Japan         =192           Asia
# 186          Israel          145           Asia
# 187     South Korea          =41           Asia
# 188         Finland         =102         Europe
# 189           Chile          201  Latin America
# 190     South Korea          =71           Asia
# 191           Chile         =137  Latin America
# 192          Brazil         =182  Latin America
# 193           China           97           Asia
# 194          Brazil          121  Latin America
# 195          Mexico         =122  Latin America
# 196           India          172           Asia
# 197           India          190           Asia
# 198           India         =179           Asia
# 199   United States           52  North America
#
#                                                  title  \
# 0    London School of Economics and Political Scien...
# 1      Ecole Polytechnique Fédérale de Lausanne (EPFL)
# 2                              Imperial College London
# 3                                Maastricht University
# 4                           Carnegie Mellon University
# 5                      UCL (University College London)
# 6                             University of St Andrews
# 7                          The University of Melbourne
# 8                      Queen Mary University of London
# 9                          The University of Hong Kong
# 10                               King's College London
# 11                             University of Groningen
# 12                           The University of Warwick
# 13                                University of Geneva
# 14                  The Australian National University
# 15                          The University of Adelaide
# 16   ETH Zurich - Swiss Federal Institute of Techno...
# 17                         The University of Edinburgh
# 18                                University of Oxford
# 19                        The University of Manchester
# 20                            The University of Sydney
# 21                                Lancaster University
# 22     The University of New South Wales (UNSW Sydney)
# 23                                   Monash University
# 24                             University of Cambridge
# 25                        City University of Hong Kong
# 26                              University of Aberdeen
# 27                         The University of Sheffield
# 28                               University of Glasgow
# 29                             University of Liverpool
# ..                                                 ...
# 170                                 Nanjing University
# 171                   Scuola Normale Superiore di Pisa
# 172                                  Tohoku University
# 173                     University of Colorado Boulder
# 174                             University of Virginia
# 175                                 Utrecht University
# 176                                   Kyoto University
# 177                      National Tsing Hua University
# 178                          Seoul National University
# 179                               Texas A&M University
# 180                                Hokkaido University
# 181          University of North Carolina, Chapel Hill
# 182                      Shanghai Jiao Tong University
# 183                               University of Bergen
# 184       Alma Mater Studiorum - University of Bologna
# 185                           Keio University CEMS MIM
# 186                 The Hebrew University of Jerusalem
# 187  KAIST - Korea Advanced Institute of Science & ...
# 188                             University of Helsinki
# 189                               Universidad de Chile
# 190  Pohang University of Science And Technology (P...
# 191      Pontificia Universidad Católica de Chile (UC)
# 179              60294.0                       4900.0                8.126845
# 180              17552.0                       1347.0                7.674339
# 181              25373.0                       1934.0                7.622276
# 182              38931.0                       2858.0                7.341193
# 183              10671.0                        767.0                7.187705
# 184              63399.0                       4195.0                6.616824
# 185              33500.0                       2178.0                6.501493
# 186              16531.0                       1034.0                6.254915
# 187               9826.0                        584.0                5.943415
# 188              22419.0                       1234.0                5.504260
# 189              38848.0                       2134.0                5.493204
# 190               3117.0                        126.0                4.042348
# 191              27003.0                        991.0                3.669963
# 192              26572.0                        966.0                3.635406
# 193              16032.0                        548.0                3.418164
# 194              65711.0                       2086.0                3.174507
# 195             141939.0                       2173.0                1.530939
# 196               7477.0                         80.0                1.069948
# 197                 47.0                        423.0                1.000000
# 198               9402.0                         93.0                0.989151
# 199                  NaN                          NaN                     NaN
#
#      QS Ratio Students/Staff  Points
# 0                  11.147541   200.0
# 1                  16.387895   199.0
# 2                  24.425109   198.0
# 3                   7.793714   197.0
# 4                  10.047919   196.0
# 5                  20.415058   195.0
# 6                  12.954545   194.0
# 7                   7.849320   193.0
# 8                  11.682677   192.0
# 9                  14.900564   191.0
# 10                 15.349033   190.0
# 11                 12.163781   189.0
# 12                 10.541425   188.0
# 13                 11.057814   187.0
# 14                 11.078798   186.0
# 15                  8.140301   185.0
# 16                 12.500631   184.0
# 17                 14.532810   183.0
# 18                 34.229209   182.0
# 19                 13.389692   181.0
# 20                  7.198252   180.0
# 21                 10.121951   179.0
# 22                  7.349688   178.0
# 23                  5.578674   177.0
# 24                 29.248801   176.0
# 25                 14.599567   175.0
# 26                 10.912120   174.0
# 27                 12.052694   173.0
# 28                 11.652320   172.0
# 29                 10.831634   171.0
# ..                       ...     ...
# 170                 7.536544    30.0
# 171                16.165414    29.0
# 172                19.133898    28.0
# 173                12.194315    27.0
# 174                11.637291    26.0
# 175                 9.658626    25.0
# 176                17.672151    24.0
# 177                 7.343413    23.0
# 178                14.003706    22.0
# 179                 5.715328    21.0
# 180                14.841613    20.0
# 181                16.091909    19.0
# 182                 9.103285    18.0
# 183                14.178615    17.0
# 184                 4.716163    16.0
# 185                11.656716    15.0
# 186                13.604743    14.0
# 187                12.721352    13.0
# 188                11.798028    12.0
# 189                 5.807249    11.0
# 190                21.302534    10.0
# 191                 8.369440     9.0
# 192                 7.406292     8.0
# 193                12.425150     7.0
# 194                 8.494773     6.0
# 195                10.619351     5.0
# 196                 6.232446     4.0
# 197                 1.000000     3.0
# 198                 9.317167     2.0
# 199                      NaN     1.0
#
# [200 rows x 12 columns]

# %% [markdown]
# ## Data from Times Higher Education ranking

# %%
URL_THE = 'https://www.timeshighereducation.com/sites/default/files/the_data_rankings/world_university_rankings_2018_limit0_369a9045a203e176392b9fb8f8c1cb2a.json'
r = requests.get(URL_THE)
page_body = r.json()
the_df = pd.DataFrame(page_body['data'])

# %%
the_df = the_df.drop(['member_level','rank_order','record_type','scores_citations', 'scores_citations_rank',\
                      'scores_overall' ,'scores_research','scores_research_rank','scores_teaching', \
                      'scores_teaching_rank','subjects_offered','scores_industry_income','scores_industry_income_rank',\
                      'scores_international_outlook','scores_international_outlook_rank', 'scores_overall',\
                     'scores_overall_rank', 'nid','stats_female_male_ratio'], axis=1).head(200)

# %%
the_df
# Out:
#                                                aliases            location  \
# 0                                 University of Oxford      United Kingdom
# 1                              University of Cambridge      United Kingdom
# 2           California Institute of Technology caltech       United States
# 3                                  Stanford University       United States
# 4                Massachusetts Institute of Technology       United States
# 5                                   Harvard University       United States
# 6                                 Princeton University       United States
# 7                              Imperial College London      United Kingdom
# 8                                University of Chicago       United States
# 9    ETH Zurich – Swiss Federal Institute of Techno...         Switzerland
# 10                          University of Pennsylvania       United States
# 11                                     Yale University       United States
# 12                            Johns Hopkins University       United States
# 13                                 Columbia University       United States
# 14               University of California, Los Angeles       United States
# 15                       University College London ucl      United Kingdom
# 16                                     Duke University       United States
# 17                  University of California, Berkeley       United States
# 18                                  Cornell University       United States
# 19                             Northwestern University       United States
# 20                              University of Michigan       United States
# 21                National University of Singapore nus           Singapore
# 22                               University of Toronto              Canada
# 23                          Carnegie Mellon University       United States
# 24    London School of Economics and Political Science      United Kingdom
# 25                            University of Washington       United States
# 26                             University of Edinburgh      United Kingdom
# 27                                 New York University       United States
# 28                                   Peking University               China
# 29   Tsinghua University Qinghua University Tsing h...               China
# ..                                                 ...                 ...
# 170                            University of Cape Town        South Africa
# 171        Rutgers, the State University of New Jersey       United States
# 172                  KTH Royal Institute of Technology              Sweden
# 173                              University of Münster             Germany
# 174                      Université Libre de Bruxelles             Belgium
# 175                               Newcastle University      United Kingdom
# 176                            University of Liverpool      United Kingdom
# 177  Zhejiang University ZJU Zhejiang University Ch...               China
# 178                           University of Luxembourg          Luxembourg
# 179                               University of Twente         Netherlands
# 180                               Paris-Sud University              France
# 181                   École Normale Supérieure de Lyon              France
# 182  Hong Kong Polytechnic University hkpu hong kon...           Hong Kong
# 183                   Scuola Normale Superiore di Pisa               Italy
# 184                             University of Aberdeen      United Kingdom
# 185                                University of Miami       United States
# 186                               University of Dundee      United Kingdom
# 187                          University of East Anglia      United Kingdom
# 188                      Shanghai Jiao Tong University               China
# 189                                   Aalto University             Finland
# 190                        University of Massachusetts       United States
# 191                             University of Auckland         New Zealand
# 192                            Northeastern University       United States
# 193                  Lomonosov Moscow State University  Russian Federation
# 194                                 Tilburg University         Netherlands
# 195                Paris-Sorbonne University – Paris 4              France
# 196               Royal Holloway, University of London      United Kingdom
# 197                University of California, Riverside       United States
# 198                           University of Gothenburg              Sweden
# 199                         National Taiwan University              Taiwan
#
#                                                   name  rank  \
# 0                                 University of Oxford     1
# 1                              University of Cambridge     2
# 2                   California Institute of Technology    =3
# 3                                  Stanford University    =3
# 4                Massachusetts Institute of Technology     5
# 5                                   Harvard University     6
# 6                                 Princeton University     7
# 7                              Imperial College London     8
# 8                                University of Chicago     9
# 9    ETH Zurich – Swiss Federal Institute of Techno...   =10
# 10                          University of Pennsylvania   =10
# 11                                     Yale University    12
# 12                            Johns Hopkins University    13
# 13                                 Columbia University    14
# 14               University of California, Los Angeles    15
# 15                           University College London    16
# 16                                     Duke University    17
# 17                  University of California, Berkeley    18
# 18                                  Cornell University    19
# 19                             Northwestern University    20
# 20                              University of Michigan    21
# 21                    National University of Singapore   =22
# 22                               University of Toronto   =22
# 23                          Carnegie Mellon University    24
# 24    London School of Economics and Political Science   =25
# 25                            University of Washington   =25
# 26                             University of Edinburgh   =27
# 27                                 New York University   =27
# 28                                   Peking University   =27
# 29                                 Tsinghua University    30
# ..                                                 ...   ...
# 170                            University of Cape Town   171
# 171        Rutgers, the State University of New Jersey   172
# 172                  KTH Royal Institute of Technology  =173
# 173                              University of Münster  =173
# 174                      Université Libre de Bruxelles  =175
# 175                               Newcastle University  =175
# 176                            University of Liverpool  =177
# 177                                Zhejiang University  =177
# 178                           University of Luxembourg  =179
# 179                               University of Twente  =179
# 180                               Paris-Sud University   181
# 181                   École Normale Supérieure de Lyon  =182
# 182                   Hong Kong Polytechnic University  =182
# 183                   Scuola Normale Superiore di Pisa   184
# 184                             University of Aberdeen   185
# 185                                University of Miami   186
# 186                               University of Dundee   187
# 187                          University of East Anglia  =188
# 188                      Shanghai Jiao Tong University  =188
# 189                                   Aalto University   190
# 190                        University of Massachusetts   191
# 191                             University of Auckland   192
# 192                            Northeastern University   193
# 193                  Lomonosov Moscow State University   194
# 194                                 Tilburg University   195
# 195                Paris-Sorbonne University – Paris 4   196
# 196               Royal Holloway, University of London   197
# 197                University of California, Riverside  =198
# 198                           University of Gothenburg  =198
# 199                         National Taiwan University  =198
#
#     stats_number_students stats_pc_intl_students stats_student_staff_ratio  \
# 0                  20,409                    38%                      11.2
# 1                  18,389                    35%                      10.9
# 2                   2,209                    27%                       6.5
# 3                  15,845                    22%                       7.5
# 4                  11,177                    34%                       8.7
# 5                  20,326                    26%                       8.9
# 6                   7,955                    24%                       8.3
# 7                  15,857                    55%                      11.4
# 8                  13,525                    25%                       6.2
# 9                  19,233                    38%                      14.6
# 10                 20,361                    20%                       6.5
# 11                 12,155                    21%                       4.3
# 12                 15,498                    24%                       4.3
# 13                 26,587                    32%                       6.1
# 14                 39,279                    17%                       9.6
# 15                 30,304                    49%                      10.5
# 16                 15,256                    22%                       4.5
# 17                 36,182                    17%                      13.1
# 18                 21,850                    24%                       9.8
# 19                 17,466                    18%                      12.8
# 20                 41,818                    16%                       8.6
# 21                 30,602                    30%                      17.0
# 22                 69,427                    17%                      18.7
# 23                 12,676                    45%                      13.5
# 24                 10,065                    71%                      12.2
# 25                 44,945                    16%                      11.4
# 26                 26,759                    40%                      12.5
# 27                 43,860                    26%                       9.6
# 28                 42,136                    16%                       8.9
# 29                 42,089                     9%                      13.7
# ..                    ...                    ...                       ...
# 170                20,775                    18%                      11.7
# 171                43,439                    10%                      11.1
# 172                12,951                    17%                      16.0
# 173                42,287                     7%                      42.6
# 174                25,343                    35%                      43.4
# 175                20,952                    30%                      15.6
# 176                19,815                    35%                      11.7
# 177                50,051                     6%                      14.1
# 178                 4,969                    57%                      14.6
# 179                 6,697                    27%                      12.8
# 180                27,221                    16%                      14.5
# 181                 2,221                    13%                       8.5
# 182                21,773                    25%                      26.9
# 183                   515                     7%                       5.2
# 184                12,055                    36%                      13.9
