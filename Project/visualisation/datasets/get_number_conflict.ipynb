# %%
import pandas as pd
import requests
import re
import numpy as np
from datetime import datetime
import os

# %%
conflict_df = pd.read_csv('clean_conflict_of_colonized_countries.csv')

# %%
conflict_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  conflictid   location                  sidea  \
# 0             3             3         201   Cambodia                 France
# 1             4             4         201   Cambodia                 France
# 2             5             5         201   Cambodia                 France
# 3             6             6         201   Cambodia                 France
# 4             7             7         201   Cambodia                 France
# 5             8             8         201   Cambodia                 France
# 6             9             9         201   Cambodia                 France
# 7            10            10         201   Cambodia                 France
# 8            19            19         204  Indonesia            Netherlands
# 9            20            20         204  Indonesia            Netherlands
# 10           21            21         204  Indonesia            Netherlands
# ...

# %%
years = conflict_df['year'].value_counts()

# %%
years_df = pd.DataFrame({'year':years.index, 'number_of_conflict':years.values})

# %%
years_df = years_df.sort_values('year')

# %%
years_df.to_csv('timeline_colonies.csv')
