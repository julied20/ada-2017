# %%
import pandas as pd
import requests
import re
import numpy as np
from datetime import datetime
import os

# %%
decolonozation_df = pd.read_csv('colonies_wikipedia.csv')

# %%
decolonozation_df;

# %%
dec_years = decolonozation_df['Year'].value_counts()

# %%
dec_years;

# %%
years_df = pd.DataFrame({'year':dec_years.index, 'number_of_decolonization':dec_years.values}).sort_values('year', ascending=True)

# %%
years_df
# Out:
#     number_of_decolonization  year
# 27                         1  1776
# 33                         1  1804
# 31                         1  1809
# 16                         2  1810
# 15                         2  1811
# 40                         1  1816
# 26                         1  1818
# 2                          8  1821
# 22                         1  1822
# 17                         2  1825
# 54                         1  1839
# 32                         1  1856
# 50                         1  1867
# 51                         1  1868
# 47                         1  1889
# 37                         1  1890
# 24                         1  1898
# 25                         1  1901
# 20                         2  1910
# 30                         1  1912
# 45                         1  1916
# 6                          4  1918
# 35                         1  1921
# 34                         1  1922
# 44                         1  1932
# 21                         1  1944
# ...

# %%
years_df.to_csv('timeline_decolonisation.csv')

# %%
years_df
# Out:
#          colonizer  number_of_conflict  year
# 3           France                   4  1946
# 2           France                   4  1947
# 13          France                   3  1948
# 12          France                   3  1949
# 11          France                   3  1950
# 10          France                   3  1951
# 9           France                   3  1952
# 0           France                   5  1953
# 1           France                   4  1954
# 7           France                   3  1955
# 6           France                   3  1956
# 5           France                   3  1957
# 4           France                   3  1958
# 14          France                   2  1959
# 16          France                   1  1960
# 8           France                   3  1961
# 15          France                   2  1962
# 19  United Kingdom                   1  1946
# 11  United Kingdom                   1  1948
# 12  United Kingdom                   1  1949
# ...

# %%
italy_df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 0.1, conflictid, location, sidea, side b, sidebid, incomp, terr, year, intensity, cumint, type, start_month, ependdate, region, ISO2, decolonisation_year, colonizer]
# Index: []
